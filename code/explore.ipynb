# %% [markdown]
# # Bill Splitter — Notebook
#
# This notebook is the **notebook interface** for the Bill Splitter. Like the
# console and Streamlit apps, it does no math of its own — it imports `bill.py`
# and calls its functions to explore different tips.
#
# Run each cell with **Shift+Enter** (choose the `/usr/local/bin/python` kernel the
# first time), or use **Run All**.

# %%
# %pip install pandas

import pandas as pd

import bill
# Out:
# 315.58s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#   Using cached numpy-2.5.2-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
# Using cached pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl (10.0 MB)
# Using cached numpy-2.5.2-cp314-cp314-macosx_14_0_arm64.whl (5.4 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# One example: a $50 bill, a 20% tip, split 4 ways.
subtotal, pct, people = 50.0, 20, 4
total = bill.grand_total(subtotal, pct)
per_person = bill.split_evenly(total, people)

print(f"Grand total: ${total:.2f}")
print(f"Each of {people} pays: ${per_person:.2f}")
per_person
# Out:
# Grand total: $1.20
# Each of 4 pays: $0.30
# 0.3

# %%
# Compare the per-person cost across a range of tip percentages.
percents = [10, 15, 18, 20, 25]
table = pd.DataFrame(
    {"per person": [bill.split_evenly(bill.grand_total(subtotal, p), people) for p in percents]},
    index=[f"{p}%" for p in percents],
)
table
# Out:
#      per person
# 10%        0.28
# 15%        0.29
# 18%        0.29
# 20%        0.30
# 25%        0.31

# %%
# A quick bar chart of the same data.
# %pip install matplotlib

import matplotlib.pyplot as plt

table.plot(kind="bar", legend=False, title="Per-person cost by tip %")
plt.ylabel("Cost per person ($)")
plt.tight_layout()
# Out:
# 377.05s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached matplotlib-3.11.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (80 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.64.0-cp314-cp314-macosx_10_15_universal2.whl.metadata (123 kB)
# ...
#   Using cached kiwisolver-1.5.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached matplotlib-3.11.1-cp314-cp314-macosx_11_0_arm64.whl (9.3 MB)
# Using cached contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.64.0-cp314-cp314-macosx_10_15_universal2.whl (3.1 MB)
# ...
